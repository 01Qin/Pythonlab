# %%
name = " "
date_returned = "27.11.2024"

# %% [markdown]
# # Lab 4
# **Exponential and logarithmic functions**<br>
# Software 2<br>
# Information and Communication Technology<br>

# %% [markdown]
# ## Setup
#
# Import necessary libraries.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1
#
# Sketch the graphs $f(x) = 2^x$ and $g(x) = (1/2)^x$ in the same graph (See Software 1, Mathematics Lectures, page 26).
#
# Use x-values ranging from -2 to +2 and having 200 linearly spaced samples. Annotate the graphics (e.g. give the xlabel, ylabel, labels for the line-plots, grid-lines, and legend).
#
# At which point do the graphs intersect? Give the intersection point for variables $x_0$ and $y_0$.

# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 200)
f = 2 ** x
g = (1/2) ** x

x0 = 0
y0 = 1

plt.grid()
plt.plot(x, f, label='f(x)')
plt.plot(x, g, label='g(x)')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Exponential function')
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 2.a
#
# The voltage of a capacitor decays exponentially (See Software 1, Mathematics Lectures Period 1.pdf, page 27):
#
# $ y(t) = \begin{cases} V_0,\; t<0 \\ V_0 \cdot e^{-t/RC}, \; t \geq 0 \end{cases}$
#
# Sketch the graph of the voltage of a capacitor in time-range -2 ms to 5 ms (included) using timestep of $0.01$ ms (Note: 1.0 ms = 0.001 s). Use the following values in calculations:
# - $V_0 = 5.0$
# - $R = 1.2 \times 10^3$
# - $C = 1.0 \times 10^{-6}$
#
# Draw in the same graph the following function
#
# $ y_2(t) = 1.5 \cdot \left( y(t) > 1.5 \right)$
#
# Annotate the graph (xlabel, ylabel, title, and grid-lines).

# %%
import numpy as np
import matplotlib.pyplot as plt

V0 = 5.0
R = 1.2e3  
C = 1.0e-6  
RC = R * C


t = np.arange(-2e-3, 5e-3, 0.01e-3)  


y = np.zeros_like(t)
y2 = np.zeros_like(t)

y[t<0] = V0
y[t>0] = V0 * np.exp(-t[t>=0]/(RC))
y2[y>1.5] = 1.5


plt.figure(figsize=(10, 6))
plt.plot(t, y, label=r'$y(t)$: Voltage of Capacitor')
plt.plot(t, y2, label=r'$y_2(t)$: Modified Voltage', linestyle='--')
plt.title('Voltage of a Capacitor vs Time')
plt.xlabel('Time (ms)')
plt.ylabel('Voltage (V)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 2.b
#
# See the previous problem. Read from the graph when the voltage is dropped below 1.5 V. Give the answer within 0.1 ms accuracy (= 4 decimals).

# %%
import numpy as np
import matplotlib.pyplot as plt

V0 = 5.0
R = 1.2e3
C = 1.0e-6
RC = R * C

t = np.arange(-2e-3, 5e-3, 0.01e-5)

y = np.zeros_like(t)
y2 = np.zeros_like(t)

y[t < 0] = V0
y[t > 0] = V0 * np.exp(-t[t >= 0] / (RC))
y2[y > 1.5] = 1.5

plt.figure(figsize=(6, 6))
plt.plot(t, y, label=r'$y(t)$: Voltage of Capacitor')
plt.plot(t, y2, label=r'$y_2(t)$: Modified Voltage', linestyle='--')
plt.title('Voltage of a Capacitor vs Time')
plt.xlabel('Time (ms)')
plt.ylabel('Voltage (V)')
plt.grid(True)
plt.xlim(0.001, 0.002)
plt.ylim(1.2, 1.8)  
plt.legend()
plt.show()

x0 = 0.001445
y0 = 1.5

plt.figure(figsize=(6, 6))
plt.plot(t, y, label=r'$y(t)$: Voltage of Capacitor')
plt.plot(t, y2, label=r'$y_2(t)$: Modified Voltage', linestyle='--')
plt.plot(x0, y0, 'ro', label=r'$(x_0, y_0)$')
plt.title('Voltage of a Capacitor vs Time')
plt.xlabel('Time (ms)')
plt.ylabel('Voltage (V)')
plt.grid(True)
plt.legend()
plt.show()

crossing_time = 0.0014

print(f"The voltage drops below 1.5 V at t = {crossing_time:.4f} seconds")
# Out:
# The voltage drops below 1.5 V at t = 0.0014 seconds

# %% [markdown]
# ## Problem 3.a
#
# The temperature of a hot cup of coffee decreases according to the formula (See Software 1, Mathematics Lectures, page 27):
#
# $ T(t) = T_{env} + (T_0 - T_{env})\cdot e^{-kt} $
#
# where,
# - $T(t)$ is the temperature of the cup of coffee
# - $T_{env}$ is the temperature of the environment
# - $T_0$ is the initial temperature of the cup of coffee
# - $k$ is the time constant
# - $t$ is time
#
# Sketch a graph of $T(t)$, when $T_{env} = 25.0$, $T_0 = 90.0$, and $k = 0.02$. Use time range from 0.0 s to 180.0 s having 200 *linearly spaced* values.
#
# Annotate the graph (grid-lines, xlabel, ylabel, title).

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
T_env = 25.0  
T_0 = 90.0  
k = 0.02  


t = np.linspace(0, 180, 200)  


T = T_env + (T_0 - T_env) * np.exp(-k * t)


plt.figure(figsize=(10, 6))
plt.plot(t, T, label='Temperature of Coffee')
plt.title('Temperature of a Hot Cup of Coffee vs Time')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 3.b
#
# See the previous problem. When has the temperature fall below 45 degrees? Give the answer within 0.1 s accuracy.

# %%
import numpy as np
import matplotlib.pyplot as plt

T_env = 25.0
T_0 = 90.0
k = 0.02

t = np.linspace(0, 180, 200)

T = T_env + (T_0 - T_env) * np.exp(-k * t)

plt.figure(figsize=(10, 6))
plt.plot(t, T, label='Temperature of Coffee')
plt.title('Temperature of a Hot Cup of Coffee vs Time')
plt.xlabel('Time (s)')
plt.ylabel('Temperature (°C)')
plt.grid(True)
plt.legend()

plt.xlim(58, 60)
plt.ylim(44.5, 45.5)

x0 = 58.94
y0 = 45
plt.plot(x0, y0, 'ro')

plt.show()

crossing_time = 58.94

print(f"The temperature falls below 45°C at t = {crossing_time:.1f} seconds")
# Out:
# The temperature falls below 45°C at t = 58.9 seconds

# %% [markdown]
# ## Problem 4
#
# Sketch the graphs of
# - $f_1(x) = x$
# - $f_2(x) = e^{x}$
# - $f_3(x) = ln(x)$
#
# using three separate axis.
#
# Draw
# - $f_1(x)$ in the first axis using lin-lin scale (`plt.plot()`)
# - $f_2(x)$ in the second axis using lin-log scale (`plt.semilogy()`)
# - $f_3(x)$ in the third axis using log-lin scale(`plt.semilogx()`).
#
# Use *logarithmically spaced values* for x to draw the graphs (e.g., `x = np.logspace(-9, 0.7, 500)`)
#
# Add grid-lines to all graphs, Use labels and legends to annotate the graphs.
#
# What do you observe? Explain it.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.logspace(-9, 0.7, 500)
f1 = x
f2 = np.exp(x)
f3 = np.log(x)

fig, ax = plt.subplots(3, 1, figsize=(4, 12))


plt.subplot(3, 1, 1)
plt.plot(x, f1, label=r'$f_1(x) = x$')
plt.xscale('linear')
plt.yscale('linear')
plt.title('Linear-Linear Plot for f1')
plt.xlabel('x')
plt.ylabel(r'$f_1(x)$')
plt.grid(True)
plt.legend()


plt.subplot(3, 1, 2)
plt.semilogy(x, f2, label=r'$f_2(x) = e^x$')
plt.title('Semilog Plot for f2')
plt.xlabel('x')
plt.ylabel(r'$f_2(x)$')
plt.grid(True)
plt.legend()


plt.subplot(3, 1, 3)
plt.plot(x, f3, label=r'$f_3(x) = \log(x)$')
plt.xscale('log')
plt.yscale('linear')
plt.title('Log-Linear Plot for f3')
plt.xlabel('x')
plt.ylabel(r'$f_3(x)$')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Observations:**

# %% [markdown]
# ## Problem 5
#
# In 1965, **[Gordon Moore](https://en.wikipedia.org/wiki/Gordon_Moore)** was asked by Electronics Magazine to predict what might happen in the semiconductor components over the next ten years. Moore observed that the numbers of components (transistors, etc.) in a dense integrated circuit had doubled approximately every year and speculated it would continue to do so for at least the next ten years. This forecast rate has been revised since then but the basic principle has continued over 50 years.
#
# Now it is your turn to make predictions. The cleaned data in file `transistors.dat` is downloaded from **[What is Moore's Law? - Our World in Data](https://ourworldindata.org/moores-law)**. You can read the data in to Notebook with the following code:
# ```python
# data = np.genfromtxt('transistors.dat', delimiter = '  ')
# year = data[:, 0]
# transistors = data[:, 1]
# ```
#
# Create two separate figures. Use `plt.figure()` commands.
#
# Draw a scatter plot of the data in the first figure using lin-lin scale, e.g. `plt.scatter(year, transistors)`. Decorate the graph, e.g. add xlabel, ylabel, title, grid-lines and so on. It is difficult to predict the output from this graph, but it serves as a linear reference. Leave it as it is and continue with the second figure.
#
# Draw a second scatter plot of the data in the second figure, but now plot the ten-base logarithmic values for the transistors, e.g. `plt.scatter(year, np.log10(transistors)`. Decorate also this graph.
#
# Try to find the linear relationship between the ten-base logarithmic values of the transistors and the years, e.g. $y(x) = k\cdot x + b$, where $x$ is the year, $k$ is the slope, $b$ is the offset, and $y$ is the estimate of `np.log10(transistors)`. Draw this estimate line in the same graph with the data, e.g. use `plt.plot(x, y)`. Use *linearly spaced values* for $x \in [1970, 2030]$. Change the xlimits and ylimits to make the graphics more readable.
#
# Find the value of $y(2030)$. Convert that back to linear scale by calculating `N = 10**y`. This is your prediction of the number of transistors in ICs at year 2030.
#
# What is your prediction?

# %%
year
# Out:
# array([1971.875     , 1972.30769231, 1974.32692308, 1979.56730769,
#        1982.30769231, 1985.91346154, 1986.25      , 1988.65384615,
#        1989.47115385, 1990.57692308, 1992.40384615, 1992.69230769,
#        1992.69230769, 1993.02884615, 1993.41346154, 1993.41346154,
#        1994.71153846, 1994.71153846, 1995.43269231, 1995.72115385,
#        1996.15384615, 1996.34615385, 1996.34615385, 1996.44230769,
#        1996.82692308, 1997.35576923, 1997.45192308, 1997.54807692,
#        1997.64423077, 1998.89423077, 1999.13461538, 1999.18269231,
#        1999.47115385, 1999.47115385, 2000.19230769, 2000.67307692,
#        2000.67307692, 2001.10576923, 2001.20192308, 2001.68269231,
#        2001.82692308, 2002.40384615, 2002.78846154, 2002.88461538,
#        2003.41346154, 2003.50961538, 2003.65384615, 2004.80769231,
#        2004.80769231, 2004.80769231, 2005.72115385, 2005.81730769,
#        2005.96153846, 2006.05769231, 2006.875     , 2006.875     ,
#        2006.92307692, 2006.97115385, 2006.97115385, 2007.06730769,
#        2007.64423077, 2007.74038462, 2007.78846154, 2007.83653846,
#        2007.98076923, 2008.22115385, 2008.46153846, 2009.18269231,
#        2009.27884615, 2009.66346154, 2009.71153846, 2010.19230769,
#        2010.38461538, 2011.16      , 2011.32      , 2011.9       ,
#        2012.4       , 2012.41      , 2012.7       , 2012.9       ,
#        2013.4       , 2013.8       , 2014.16      , 2014.5       ,
#        2014.8       , 2014.81      , 2014.82      , 2016.33      ,
#        2016.67      , 2017.5       , 2018.4       , 2018.5       ,
#        2019.3       , 2019.8       , 2020.1       , 2020.9       ,
#        2021.8       , 2021.9       , 2021.9       ])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

data = np.genfromtxt('transistors.dat', delimiter='  ')
year = data[:, 0]
transistors = data[:, 1]


fig1 = plt.figure()
plt.scatter(year, transistors, color='blue', label='Transistor Count')
plt.title('Transistor Count vs Year (Linear Scale)')
plt.xlabel('Year')
plt.ylabel('Number of Transistors')
plt.grid(True)
plt.legend()
plt.show()


log_transistors = np.log10(transistors)


slope, intercept, r_value, p_value, std_err = linregress(year, log_transistors)
print(f"Slope: {slope}, Intercept: {intercept}, R-squared: {r_value**2}")


x_fit = np.arange(2017, 2030, 1)
y_fit = slope * x_fit + intercept


fig2 = plt.figure()
plt.scatter(year, log_transistors, color='blue', label='Log Transistor Count')
plt.plot(x_fit, y_fit, color='red', label=f'Fit: log10(Transistors) = {slope:.4f} * Year + {intercept:.4f}')
plt.title('Log10(Transistor Count) vs Year')
plt.xlabel('Year')
plt.ylabel('Log10(Number of Transistors)')
plt.grid(True)
plt.legend()
plt.show()


year_2030 = 2030
log_transistors_2030 = slope * year_2030 + intercept
transistors_2030 = 10**log_transistors_2030
print(f"Predicted number of transistors in 2030: {transistors_2030:.2e}")
# Out:
# Slope: 0.1508931760344799, Intercept: -297.4079602629018, R-squared: 0.9797167010076013
# Predicted number of transistors in 2030: 8.04e+08
